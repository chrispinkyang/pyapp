# %%
import random

# 随机字母:
def rndChar():
    return chr(random.randint(65, 90))

# 随机颜色1:
def rndColor():
    return (random.randint(64, 255), random.randint(64, 255), random.randint(64, 255))

# 随机颜色2:
def rndColor2():
    return (random.randint(32, 127), random.randint(32, 127), random.randint(32, 127))

# %%
from PIL import Image

# %%
im = Image.new('RGB', (240, 60), (255, 255, 255))

# %%
from PIL import ImageDraw,ImageFont

# %%
font = ImageFont.truetype('C:/Windows/Fonts/Arial.ttf',36)

# %%
draw = ImageDraw.Draw(im)

# %%
for x in range(240):
    for y in range(60):
        draw.point((x,y),fill=rndColor())
for i in range(4):
    draw.text((60*i + 10,10),rndChar(),font=font,fill=rndColor2())

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=240x60 at 0x1431ADA47F0>

# %%
from PIL import ImageFilter
image = im.filter(ImageFilter.BLUR)

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=240x60 at 0x1431ADA47F0>

# %%
image = image.filter(ImageFilter.GaussianBlur)

# %%
image.save('image.jpeg','JPEG')

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2017, 11, 22, 17, 46, 27, 956873)

# %%
datetime.date()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c3db7d1b2d07> in <module>()
# ----> 1 datetime.date()
#
# TypeError: descriptor 'date' of 'datetime.datetime' object needs an argument

# %%
d = datetime.now()

# %%
d.strftime()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-9d3910a5c8b1> in <module>()
# ----> 1 d.strftime()
#
# TypeError: Required argument 'format' (pos 1) not found

# %%
r = random.random()

# %%
r
# Out:
# 0.9667817880475336

# %%
int(r*100)
# Out:
# 96
